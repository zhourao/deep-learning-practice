# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('./data/random_data.csv')
data.shape
# Out:
# (4930161, 17)

# %%
data.head()
# Out:
#    label                   C1                   C2                   C3  \
# 0      0  4110010518477440242  1896312013845627886  6717084795003240529
# 1      0  8549798872825571966  1896312013845627886  5931133767701417382
# 2      0  8549798872825571966  1896312013845627886  5931133767701417382
# 3      1  4110010518477440242  1896312013845627886  6738940029233988884
# 4      0   754307468715170673  1896312013845627886  4744813893973488598
#
#                     C4                   C5                   C6  \
# 0  1080695977093114212  4111614179005464985  8798042721559307282
# 1  1080695977093114212  6220860133300853649  8798042721559307282
# 2  1080695977093114212  6220860133300853649  8798042721559307282
# 3  1080695977093114212  4111614179005464985  4661809481046063301
# 4  1080695977093114212  4111614179005464985  8798042721559307282
#
#                     C7                   C8                   C9  \
# 0  5895132605950582744  6084180829892317120  7697383445739955609
# 1  7906599642295772887  8074429082947521887  2016335991759856420
# 2  5895132605950582744  6084180829892317120  7697383445739955609
# 3  4860738004335111677  9151208213879479282   287166139677673559
# 4  3365621371127355288  8074429082947521887  8049740328582698059
#
#                    C10                  C11                  C12  \
# 0  4884422954281974949  8336763477901001868  6242285785126424193
# 1  8321822893668424639  6374970459031672275  2638981520939704579
# 2  4884422954281974949  8336763477901001868  6242285785126424193
# 3  3794272402836699782  4828615104526241983  6674460745934457691
# 4  9094510792016618155  1867504036779671592  3042470253253863991
#
#                    C13                  C14     I1          I2
# 0  7900538574498788796   134740763003655426  128.0  2996580352
# 1  1276775102817461451  7804158046819701007    0.0  3960238080
# 2  7900538574498788796   134740763003655426  128.0  2996584448
# 3  1276775102817461451   134740763003655426  102.0  5837828096
# 4  1276775102817461451   134740763003655426   92.0  3950256128

# %%
cols = data.columns.values
CATEGORICAL_COLS = [f for f in cols if f[0] == "C"] # C开头是类别特征
data[CATEGORICAL_COLS] = data[CATEGORICAL_COLS].fillna('unkown')

CATEGORICAL_COLS
# Out:
# ['C1',
#  'C2',
#  'C3',
#  'C4',
#  'C5',
#  'C6',
#  'C7',
#  'C8',
#  'C9',
#  'C10',
#  'C11',
#  'C12',
#  'C13',
#  'C14']

# %%
from sklearn.model_selection import KFold, cross_val_score
from sklearn.preprocessing import LabelEncoder

def encodeColumns(sdf, colnames):
    df = sdf
    labelEncoderDict = {}
    for col in colnames:
        labelEncoderDict[col] = {}
        le = LabelEncoder()
        df[col] = le.fit_transform(df[col].astype(str))
        clas = le.classes_
        for i in range(0, len(clas)):
            labelEncoderDict[col][clas[i]] = i
 
    return df, labelEncoderDict

data, le_dict = encodeColumns(data, CATEGORICAL_COLS)

# %%
df_train = data.loc[:3500000-1]

y_train = df_train["label"]
X_train = df_train.drop(columns=["label"])

X_train.shape, y_train.shape
# Out:
# ((3500000, 16), (3500000,))

# %%
df_test = data.loc[3500000:]
y_test = df_test["label"]
X_test = df_test.drop(columns=["label"])

X_test.shape, y_test.shape
# Out:
# ((1430161, 16), (1430161,))

# %%
import lightgbm
lgb_train = lightgbm.Dataset(data=X_train, label=y_train, 
                             categorical_feature=CATEGORICAL_COLS, 
                             free_raw_data=False)

lgb_valid = lightgbm.Dataset(data=X_test, label=y_test, 
                             categorical_feature=CATEGORICAL_COLS, 
                             free_raw_data=False)

params = {
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': {'binary_logloss','xentropy','auc'},
    'num_leaves': 200, #<2^depth
    'max_depth':9,
    'learning_rate': 0.06,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.9,
    'min_data_in_leaf': 300,
    'max_bin': 1000,
    'lambda_l1': 1,             #l1正则
#     'lambda_l2': 0.001,     #l2正则
    'is_unbalance':True, ###
    'bagging_freq': 5, #每 k 次迭代执行bagging
    'verbose': 1,# <0 显示致命的, =0 显示错误 (警告), >0 显示信息
    'num_iterations':300
    }
 
gbm = lightgbm.train(params, lgb_train, valid_sets=[lgb_valid])
# Out:
# /opt/conda/lib/python3.8/site-packages/lightgbm/engine.py:148: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning("Found `{}` in params. Will use it instead of argument".format(alias))
# /opt/conda/lib/python3.8/site-packages/lightgbm/basic.py:1702: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# [LightGBM] [Info] Number of positive: 419054, number of negative: 3080946
# [LightGBM] [Info] [cross_entropy:Init]: (metric) labels passed interval [0, 1] check
# [LightGBM] [Info] [cross_entropy:Init]: sum-of-weights = 3500000.000000
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.880930 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6020
# [LightGBM] [Info] Number of data points in the train set: 3500000, number of used features: 16
# /opt/conda/lib/python3.8/site-packages/lightgbm/basic.py:1433: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /opt/conda/lib/python3.8/site-packages/lightgbm/basic.py:1245: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Info] [cross_entropy:Init]: (metric) labels passed interval [0, 1] check
# [LightGBM] [Info] [cross_entropy:Init]: sum-of-weights = 1430161.000000
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.119730 -> initscore=-1.994992
# [LightGBM] [Info] Start training from score -1.994992
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's cross_entropy: 0.311487	valid_0's binary_logloss: 0.311487	valid_0's auc: 0.98567
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid_0's cross_entropy: 0.278331	valid_0's binary_logloss: 0.278331	valid_0's auc: 0.987702
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid_0's cross_entropy: 0.252793	valid_0's binary_logloss: 0.252793	valid_0's auc: 0.99116
# [4]	valid_0's cross_entropy: 0.232263	valid_0's binary_logloss: 0.232263	valid_0's auc: 0.994879
# [5]	valid_0's cross_entropy: 0.214937	valid_0's binary_logloss: 0.214937	valid_0's auc: 0.995389
# [95]	valid_0's cross_entropy: 0.0415385	valid_0's binary_logloss: 0.0415385	valid_0's auc: 0.997669
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [96]	valid_0's cross_entropy: 0.0414831	valid_0's binary_logloss: 0.0414831	valid_0's auc: 0.997673
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [97]	valid_0's cross_entropy: 0.041437	valid_0's binary_logloss: 0.041437	valid_0's auc: 0.997675
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [98]	valid_0's cross_entropy: 0.0413927	valid_0's binary_logloss: 0.0413927	valid_0's auc: 0.997677
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [99]	valid_0's cross_entropy: 0.0413407	valid_0's binary_logloss: 0.0413407	valid_0's auc: 0.997678
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	valid_0's cross_entropy: 0.0412993	valid_0's binary_logloss: 0.0412993	valid_0's auc: 0.997678
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [101]	valid_0's cross_entropy: 0.041199	valid_0's binary_logloss: 0.041199	valid_0's auc: 0.997684
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [102]	valid_0's cross_entropy: 0.0411091	valid_0's binary_logloss: 0.0411091	valid_0's auc: 0.997688
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [103]	valid_0's cross_entropy: 0.0410587	valid_0's binary_logloss: 0.0410587	valid_0's auc: 0.997691
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [104]	valid_0's cross_entropy: 0.0410204	valid_0's binary_logloss: 0.0410204	valid_0's auc: 0.997694
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [105]	valid_0's cross_entropy: 0.0409535	valid_0's binary_logloss: 0.0409535	valid_0's auc: 0.997698
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [106]	valid_0's cross_entropy: 0.0408908	valid_0's binary_logloss: 0.0408908	valid_0's auc: 0.997701
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [107]	valid_0's cross_entropy: 0.0408521	valid_0's binary_logloss: 0.0408521	valid_0's auc: 0.997703
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [108]	valid_0's cross_entropy: 0.0408221	valid_0's binary_logloss: 0.0408221	valid_0's auc: 0.997704
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [109]	valid_0's cross_entropy: 0.040771	valid_0's binary_logloss: 0.040771	valid_0's auc: 0.997706
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [110]	valid_0's cross_entropy: 0.0407125	valid_0's binary_logloss: 0.0407125	valid_0's auc: 0.997709
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [111]	valid_0's cross_entropy: 0.0405943	valid_0's binary_logloss: 0.0405943	valid_0's auc: 0.997721
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [112]	valid_0's cross_entropy: 0.0405738	valid_0's binary_logloss: 0.0405738	valid_0's auc: 0.997721
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [113]	valid_0's cross_entropy: 0.0404947	valid_0's binary_logloss: 0.0404947	valid_0's auc: 0.997725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [114]	valid_0's cross_entropy: 0.0404793	valid_0's binary_logloss: 0.0404793	valid_0's auc: 0.997726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [115]	valid_0's cross_entropy: 0.0404605	valid_0's binary_logloss: 0.0404605	valid_0's auc: 0.997727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [116]	valid_0's cross_entropy: 0.0403813	valid_0's binary_logloss: 0.0403813	valid_0's auc: 0.997732
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [117]	valid_0's cross_entropy: 0.0403264	valid_0's binary_logloss: 0.0403264	valid_0's auc: 0.997738
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [118]	valid_0's cross_entropy: 0.0402838	valid_0's binary_logloss: 0.0402838	valid_0's auc: 0.997741
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [119]	valid_0's cross_entropy: 0.0402475	valid_0's binary_logloss: 0.0402475	valid_0's auc: 0.99774
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [120]	valid_0's cross_entropy: 0.0401973	valid_0's binary_logloss: 0.0401973	valid_0's auc: 0.997743
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [121]	valid_0's cross_entropy: 0.0401794	valid_0's binary_logloss: 0.0401794	valid_0's auc: 0.997743
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [122]	valid_0's cross_entropy: 0.0401635	valid_0's binary_logloss: 0.0401635	valid_0's auc: 0.997742
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [123]	valid_0's cross_entropy: 0.0401329	valid_0's binary_logloss: 0.0401329	valid_0's auc: 0.997743
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [124]	valid_0's cross_entropy: 0.0401222	valid_0's binary_logloss: 0.0401222	valid_0's auc: 0.997742
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [125]	valid_0's cross_entropy: 0.0400737	valid_0's binary_logloss: 0.0400737	valid_0's auc: 0.997743
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [126]	valid_0's cross_entropy: 0.0400476	valid_0's binary_logloss: 0.0400476	valid_0's auc: 0.997744
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [127]	valid_0's cross_entropy: 0.0400327	valid_0's binary_logloss: 0.0400327	valid_0's auc: 0.997745
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [128]	valid_0's cross_entropy: 0.0399899	valid_0's binary_logloss: 0.0399899	valid_0's auc: 0.997745
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [129]	valid_0's cross_entropy: 0.0399685	valid_0's binary_logloss: 0.0399685	valid_0's auc: 0.997744
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [130]	valid_0's cross_entropy: 0.0399558	valid_0's binary_logloss: 0.0399558	valid_0's auc: 0.997744
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [131]	valid_0's cross_entropy: 0.0399128	valid_0's binary_logloss: 0.0399128	valid_0's auc: 0.997747
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [132]	valid_0's cross_entropy: 0.0398833	valid_0's binary_logloss: 0.0398833	valid_0's auc: 0.99775
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [133]	valid_0's cross_entropy: 0.0398706	valid_0's binary_logloss: 0.0398706	valid_0's auc: 0.99775
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [134]	valid_0's cross_entropy: 0.0397853	valid_0's binary_logloss: 0.0397853	valid_0's auc: 0.997756
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [135]	valid_0's cross_entropy: 0.0397598	valid_0's binary_logloss: 0.0397598	valid_0's auc: 0.997757
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [136]	valid_0's cross_entropy: 0.0397108	valid_0's binary_logloss: 0.0397108	valid_0's auc: 0.997759
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [137]	valid_0's cross_entropy: 0.0396239	valid_0's binary_logloss: 0.0396239	valid_0's auc: 0.997764
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [138]	valid_0's cross_entropy: 0.0396126	valid_0's binary_logloss: 0.0396126	valid_0's auc: 0.997764
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [139]	valid_0's cross_entropy: 0.0395806	valid_0's binary_logloss: 0.0395806	valid_0's auc: 0.997766
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [140]	valid_0's cross_entropy: 0.0395368	valid_0's binary_logloss: 0.0395368	valid_0's auc: 0.997768
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [141]	valid_0's cross_entropy: 0.0394754	valid_0's binary_logloss: 0.0394754	valid_0's auc: 0.997772
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [142]	valid_0's cross_entropy: 0.0394221	valid_0's binary_logloss: 0.0394221	valid_0's auc: 0.997774
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [143]	valid_0's cross_entropy: 0.0393775	valid_0's binary_logloss: 0.0393775	valid_0's auc: 0.997775
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [144]	valid_0's cross_entropy: 0.0393532	valid_0's binary_logloss: 0.0393532	valid_0's auc: 0.997776
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [145]	valid_0's cross_entropy: 0.0393313	valid_0's binary_logloss: 0.0393313	valid_0's auc: 0.997776
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [146]	valid_0's cross_entropy: 0.0392995	valid_0's binary_logloss: 0.0392995	valid_0's auc: 0.997777
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [147]	valid_0's cross_entropy: 0.0392749	valid_0's binary_logloss: 0.0392749	valid_0's auc: 0.997777
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [148]	valid_0's cross_entropy: 0.0392114	valid_0's binary_logloss: 0.0392114	valid_0's auc: 0.997779
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [149]	valid_0's cross_entropy: 0.0391765	valid_0's binary_logloss: 0.0391765	valid_0's auc: 0.997782
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [150]	valid_0's cross_entropy: 0.0391568	valid_0's binary_logloss: 0.0391568	valid_0's auc: 0.997782
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [151]	valid_0's cross_entropy: 0.0391434	valid_0's binary_logloss: 0.0391434	valid_0's auc: 0.997783
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [152]	valid_0's cross_entropy: 0.0391085	valid_0's binary_logloss: 0.0391085	valid_0's auc: 0.997786
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [153]	valid_0's cross_entropy: 0.0391012	valid_0's binary_logloss: 0.0391012	valid_0's auc: 0.997785
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [154]	valid_0's cross_entropy: 0.0390755	valid_0's binary_logloss: 0.0390755	valid_0's auc: 0.997786
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [155]	valid_0's cross_entropy: 0.039065	valid_0's binary_logloss: 0.039065	valid_0's auc: 0.997785
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [156]	valid_0's cross_entropy: 0.0390417	valid_0's binary_logloss: 0.0390417	valid_0's auc: 0.997786
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [157]	valid_0's cross_entropy: 0.0389894	valid_0's binary_logloss: 0.0389894	valid_0's auc: 0.997788
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [158]	valid_0's cross_entropy: 0.0389783	valid_0's binary_logloss: 0.0389783	valid_0's auc: 0.997787
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [159]	valid_0's cross_entropy: 0.0389497	valid_0's binary_logloss: 0.0389497	valid_0's auc: 0.997788
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [160]	valid_0's cross_entropy: 0.0388954	valid_0's binary_logloss: 0.0388954	valid_0's auc: 0.997791
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [161]	valid_0's cross_entropy: 0.0388778	valid_0's binary_logloss: 0.0388778	valid_0's auc: 0.997791
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [162]	valid_0's cross_entropy: 0.0388666	valid_0's binary_logloss: 0.0388666	valid_0's auc: 0.997791
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [163]	valid_0's cross_entropy: 0.0388322	valid_0's binary_logloss: 0.0388322	valid_0's auc: 0.997794
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [164]	valid_0's cross_entropy: 0.0388229	valid_0's binary_logloss: 0.0388229	valid_0's auc: 0.997795
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [165]	valid_0's cross_entropy: 0.0388211	valid_0's binary_logloss: 0.0388211	valid_0's auc: 0.997795
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [166]	valid_0's cross_entropy: 0.0387975	valid_0's binary_logloss: 0.0387975	valid_0's auc: 0.997797
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [167]	valid_0's cross_entropy: 0.0387783	valid_0's binary_logloss: 0.0387783	valid_0's auc: 0.997797
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [168]	valid_0's cross_entropy: 0.0387655	valid_0's binary_logloss: 0.0387655	valid_0's auc: 0.997797
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [169]	valid_0's cross_entropy: 0.0387246	valid_0's binary_logloss: 0.0387246	valid_0's auc: 0.997799
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [170]	valid_0's cross_entropy: 0.0387122	valid_0's binary_logloss: 0.0387122	valid_0's auc: 0.997799
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [171]	valid_0's cross_entropy: 0.0386683	valid_0's binary_logloss: 0.0386683	valid_0's auc: 0.997802
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [172]	valid_0's cross_entropy: 0.0386523	valid_0's binary_logloss: 0.0386523	valid_0's auc: 0.997803
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [173]	valid_0's cross_entropy: 0.038618	valid_0's binary_logloss: 0.038618	valid_0's auc: 0.997806
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [174]	valid_0's cross_entropy: 0.0385957	valid_0's binary_logloss: 0.0385957	valid_0's auc: 0.997807
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [175]	valid_0's cross_entropy: 0.0385771	valid_0's binary_logloss: 0.0385771	valid_0's auc: 0.997808
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [176]	valid_0's cross_entropy: 0.0385685	valid_0's binary_logloss: 0.0385685	valid_0's auc: 0.997808
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [177]	valid_0's cross_entropy: 0.0385338	valid_0's binary_logloss: 0.0385338	valid_0's auc: 0.997811
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [178]	valid_0's cross_entropy: 0.0385272	valid_0's binary_logloss: 0.0385272	valid_0's auc: 0.99781
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [179]	valid_0's cross_entropy: 0.0384885	valid_0's binary_logloss: 0.0384885	valid_0's auc: 0.997812
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [180]	valid_0's cross_entropy: 0.038461	valid_0's binary_logloss: 0.038461	valid_0's auc: 0.997813
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [181]	valid_0's cross_entropy: 0.0384109	valid_0's binary_logloss: 0.0384109	valid_0's auc: 0.997817
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [182]	valid_0's cross_entropy: 0.0383882	valid_0's binary_logloss: 0.0383882	valid_0's auc: 0.997817
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [183]	valid_0's cross_entropy: 0.038344	valid_0's binary_logloss: 0.038344	valid_0's auc: 0.99782
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [184]	valid_0's cross_entropy: 0.0383294	valid_0's binary_logloss: 0.0383294	valid_0's auc: 0.997818
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [185]	valid_0's cross_entropy: 0.0383223	valid_0's binary_logloss: 0.0383223	valid_0's auc: 0.997818
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [186]	valid_0's cross_entropy: 0.038299	valid_0's binary_logloss: 0.038299	valid_0's auc: 0.997818
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [187]	valid_0's cross_entropy: 0.038279	valid_0's binary_logloss: 0.038279	valid_0's auc: 0.997819
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [188]	valid_0's cross_entropy: 0.0382741	valid_0's binary_logloss: 0.0382741	valid_0's auc: 0.997818
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [189]	valid_0's cross_entropy: 0.0382097	valid_0's binary_logloss: 0.0382097	valid_0's auc: 0.997822
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [190]	valid_0's cross_entropy: 0.0381935	valid_0's binary_logloss: 0.0381935	valid_0's auc: 0.997822
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [191]	valid_0's cross_entropy: 0.0381628	valid_0's binary_logloss: 0.0381628	valid_0's auc: 0.997823
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [192]	valid_0's cross_entropy: 0.038115	valid_0's binary_logloss: 0.038115	valid_0's auc: 0.997825
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [193]	valid_0's cross_entropy: 0.038104	valid_0's binary_logloss: 0.038104	valid_0's auc: 0.997825
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [194]	valid_0's cross_entropy: 0.0380665	valid_0's binary_logloss: 0.0380665	valid_0's auc: 0.997826
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [195]	valid_0's cross_entropy: 0.0380586	valid_0's binary_logloss: 0.0380586	valid_0's auc: 0.997826
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [196]	valid_0's cross_entropy: 0.0380476	valid_0's binary_logloss: 0.0380476	valid_0's auc: 0.997825
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [197]	valid_0's cross_entropy: 0.0380229	valid_0's binary_logloss: 0.0380229	valid_0's auc: 0.997826
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [198]	valid_0's cross_entropy: 0.0380178	valid_0's binary_logloss: 0.0380178	valid_0's auc: 0.997825
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [199]	valid_0's cross_entropy: 0.0380049	valid_0's binary_logloss: 0.0380049	valid_0's auc: 0.997824
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [200]	valid_0's cross_entropy: 0.0379743	valid_0's binary_logloss: 0.0379743	valid_0's auc: 0.997825
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [201]	valid_0's cross_entropy: 0.0379647	valid_0's binary_logloss: 0.0379647	valid_0's auc: 0.997827
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [202]	valid_0's cross_entropy: 0.0379538	valid_0's binary_logloss: 0.0379538	valid_0's auc: 0.997827
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [203]	valid_0's cross_entropy: 0.037944	valid_0's binary_logloss: 0.037944	valid_0's auc: 0.997829
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [204]	valid_0's cross_entropy: 0.0379036	valid_0's binary_logloss: 0.0379036	valid_0's auc: 0.997832
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [205]	valid_0's cross_entropy: 0.0378744	valid_0's binary_logloss: 0.0378744	valid_0's auc: 0.997833
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [206]	valid_0's cross_entropy: 0.0378597	valid_0's binary_logloss: 0.0378597	valid_0's auc: 0.997834
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [207]	valid_0's cross_entropy: 0.0378212	valid_0's binary_logloss: 0.0378212	valid_0's auc: 0.997835
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [208]	valid_0's cross_entropy: 0.0377877	valid_0's binary_logloss: 0.0377877	valid_0's auc: 0.997836
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [209]	valid_0's cross_entropy: 0.037758	valid_0's binary_logloss: 0.037758	valid_0's auc: 0.997838
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [210]	valid_0's cross_entropy: 0.0377207	valid_0's binary_logloss: 0.0377207	valid_0's auc: 0.997839
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [211]	valid_0's cross_entropy: 0.0376931	valid_0's binary_logloss: 0.0376931	valid_0's auc: 0.997839
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [212]	valid_0's cross_entropy: 0.0376741	valid_0's binary_logloss: 0.0376741	valid_0's auc: 0.99784
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [213]	valid_0's cross_entropy: 0.0376728	valid_0's binary_logloss: 0.0376728	valid_0's auc: 0.99784
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [214]	valid_0's cross_entropy: 0.0376673	valid_0's binary_logloss: 0.0376673	valid_0's auc: 0.99784
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [215]	valid_0's cross_entropy: 0.0376593	valid_0's binary_logloss: 0.0376593	valid_0's auc: 0.99784
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [216]	valid_0's cross_entropy: 0.037643	valid_0's binary_logloss: 0.037643	valid_0's auc: 0.99784
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [217]	valid_0's cross_entropy: 0.0376307	valid_0's binary_logloss: 0.0376307	valid_0's auc: 0.99784
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [218]	valid_0's cross_entropy: 0.0375911	valid_0's binary_logloss: 0.0375911	valid_0's auc: 0.99784
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [219]	valid_0's cross_entropy: 0.0375646	valid_0's binary_logloss: 0.0375646	valid_0's auc: 0.99784
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [220]	valid_0's cross_entropy: 0.0375287	valid_0's binary_logloss: 0.0375287	valid_0's auc: 0.997841
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [221]	valid_0's cross_entropy: 0.0375145	valid_0's binary_logloss: 0.0375145	valid_0's auc: 0.997842
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [222]	valid_0's cross_entropy: 0.037491	valid_0's binary_logloss: 0.037491	valid_0's auc: 0.997842
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [223]	valid_0's cross_entropy: 0.0374678	valid_0's binary_logloss: 0.0374678	valid_0's auc: 0.997842
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [224]	valid_0's cross_entropy: 0.0374534	valid_0's binary_logloss: 0.0374534	valid_0's auc: 0.997843
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [225]	valid_0's cross_entropy: 0.0374468	valid_0's binary_logloss: 0.0374468	valid_0's auc: 0.997843
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [226]	valid_0's cross_entropy: 0.0374338	valid_0's binary_logloss: 0.0374338	valid_0's auc: 0.997843
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [227]	valid_0's cross_entropy: 0.037422	valid_0's binary_logloss: 0.037422	valid_0's auc: 0.997843
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [228]	valid_0's cross_entropy: 0.0374152	valid_0's binary_logloss: 0.0374152	valid_0's auc: 0.997843
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [229]	valid_0's cross_entropy: 0.0374032	valid_0's binary_logloss: 0.0374032	valid_0's auc: 0.997842
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [230]	valid_0's cross_entropy: 0.0373912	valid_0's binary_logloss: 0.0373912	valid_0's auc: 0.997842
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [231]	valid_0's cross_entropy: 0.0373814	valid_0's binary_logloss: 0.0373814	valid_0's auc: 0.997842
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [232]	valid_0's cross_entropy: 0.037376	valid_0's binary_logloss: 0.037376	valid_0's auc: 0.997841
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [233]	valid_0's cross_entropy: 0.0373665	valid_0's binary_logloss: 0.0373665	valid_0's auc: 0.997842
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [234]	valid_0's cross_entropy: 0.0373509	valid_0's binary_logloss: 0.0373509	valid_0's auc: 0.997842
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [235]	valid_0's cross_entropy: 0.0373202	valid_0's binary_logloss: 0.0373202	valid_0's auc: 0.997842
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [236]	valid_0's cross_entropy: 0.0373146	valid_0's binary_logloss: 0.0373146	valid_0's auc: 0.997842
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [237]	valid_0's cross_entropy: 0.0372981	valid_0's binary_logloss: 0.0372981	valid_0's auc: 0.997841
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [238]	valid_0's cross_entropy: 0.0372938	valid_0's binary_logloss: 0.0372938	valid_0's auc: 0.997841
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [239]	valid_0's cross_entropy: 0.0372868	valid_0's binary_logloss: 0.0372868	valid_0's auc: 0.99784
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [240]	valid_0's cross_entropy: 0.0372716	valid_0's binary_logloss: 0.0372716	valid_0's auc: 0.997841
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [241]	valid_0's cross_entropy: 0.0372489	valid_0's binary_logloss: 0.0372489	valid_0's auc: 0.997842
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [242]	valid_0's cross_entropy: 0.0372313	valid_0's binary_logloss: 0.0372313	valid_0's auc: 0.997842
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [243]	valid_0's cross_entropy: 0.037217	valid_0's binary_logloss: 0.037217	valid_0's auc: 0.997843
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [244]	valid_0's cross_entropy: 0.0371979	valid_0's binary_logloss: 0.0371979	valid_0's auc: 0.997843
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [245]	valid_0's cross_entropy: 0.0371762	valid_0's binary_logloss: 0.0371762	valid_0's auc: 0.997843
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [246]	valid_0's cross_entropy: 0.0371603	valid_0's binary_logloss: 0.0371603	valid_0's auc: 0.997844
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [247]	valid_0's cross_entropy: 0.0371464	valid_0's binary_logloss: 0.0371464	valid_0's auc: 0.997845
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [248]	valid_0's cross_entropy: 0.0371333	valid_0's binary_logloss: 0.0371333	valid_0's auc: 0.997844
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [249]	valid_0's cross_entropy: 0.0371251	valid_0's binary_logloss: 0.0371251	valid_0's auc: 0.997844
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [250]	valid_0's cross_entropy: 0.0371104	valid_0's binary_logloss: 0.0371104	valid_0's auc: 0.997844
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [251]	valid_0's cross_entropy: 0.0370724	valid_0's binary_logloss: 0.0370724	valid_0's auc: 0.997845
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [252]	valid_0's cross_entropy: 0.0370668	valid_0's binary_logloss: 0.0370668	valid_0's auc: 0.997845
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [253]	valid_0's cross_entropy: 0.0370392	valid_0's binary_logloss: 0.0370392	valid_0's auc: 0.997845
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [254]	valid_0's cross_entropy: 0.0370202	valid_0's binary_logloss: 0.0370202	valid_0's auc: 0.997846
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [255]	valid_0's cross_entropy: 0.0369851	valid_0's binary_logloss: 0.0369851	valid_0's auc: 0.997847
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [256]	valid_0's cross_entropy: 0.0369186	valid_0's binary_logloss: 0.0369186	valid_0's auc: 0.997851
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [257]	valid_0's cross_entropy: 0.0369042	valid_0's binary_logloss: 0.0369042	valid_0's auc: 0.997851
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [258]	valid_0's cross_entropy: 0.03689	valid_0's binary_logloss: 0.03689	valid_0's auc: 0.997851
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [259]	valid_0's cross_entropy: 0.0368555	valid_0's binary_logloss: 0.0368555	valid_0's auc: 0.997852
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [260]	valid_0's cross_entropy: 0.0368373	valid_0's binary_logloss: 0.0368373	valid_0's auc: 0.997851
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [261]	valid_0's cross_entropy: 0.0368284	valid_0's binary_logloss: 0.0368284	valid_0's auc: 0.997851
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [262]	valid_0's cross_entropy: 0.0368197	valid_0's binary_logloss: 0.0368197	valid_0's auc: 0.997851
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [263]	valid_0's cross_entropy: 0.0367596	valid_0's binary_logloss: 0.0367596	valid_0's auc: 0.997855
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [264]	valid_0's cross_entropy: 0.0367511	valid_0's binary_logloss: 0.0367511	valid_0's auc: 0.997855
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [265]	valid_0's cross_entropy: 0.0367441	valid_0's binary_logloss: 0.0367441	valid_0's auc: 0.997855
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [266]	valid_0's cross_entropy: 0.0367074	valid_0's binary_logloss: 0.0367074	valid_0's auc: 0.997857
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [267]	valid_0's cross_entropy: 0.0366988	valid_0's binary_logloss: 0.0366988	valid_0's auc: 0.997857
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [268]	valid_0's cross_entropy: 0.0366723	valid_0's binary_logloss: 0.0366723	valid_0's auc: 0.997859
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [269]	valid_0's cross_entropy: 0.0366437	valid_0's binary_logloss: 0.0366437	valid_0's auc: 0.99786
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [270]	valid_0's cross_entropy: 0.0366322	valid_0's binary_logloss: 0.0366322	valid_0's auc: 0.997861
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [271]	valid_0's cross_entropy: 0.0366036	valid_0's binary_logloss: 0.0366036	valid_0's auc: 0.997861
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [272]	valid_0's cross_entropy: 0.0365728	valid_0's binary_logloss: 0.0365728	valid_0's auc: 0.997863
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [273]	valid_0's cross_entropy: 0.0365454	valid_0's binary_logloss: 0.0365454	valid_0's auc: 0.997863
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [274]	valid_0's cross_entropy: 0.0365361	valid_0's binary_logloss: 0.0365361	valid_0's auc: 0.997861
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [275]	valid_0's cross_entropy: 0.0365218	valid_0's binary_logloss: 0.0365218	valid_0's auc: 0.997862
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [276]	valid_0's cross_entropy: 0.0364912	valid_0's binary_logloss: 0.0364912	valid_0's auc: 0.997863
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [277]	valid_0's cross_entropy: 0.0364706	valid_0's binary_logloss: 0.0364706	valid_0's auc: 0.997864
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [278]	valid_0's cross_entropy: 0.036451	valid_0's binary_logloss: 0.036451	valid_0's auc: 0.997865
# [279]	valid_0's cross_entropy: 0.0364041	valid_0's binary_logloss: 0.0364041	valid_0's auc: 0.997866
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [280]	valid_0's cross_entropy: 0.0363661	valid_0's binary_logloss: 0.0363661	valid_0's auc: 0.997867
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [281]	valid_0's cross_entropy: 0.0363594	valid_0's binary_logloss: 0.0363594	valid_0's auc: 0.997867
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [282]	valid_0's cross_entropy: 0.0363498	valid_0's binary_logloss: 0.0363498	valid_0's auc: 0.997867
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [283]	valid_0's cross_entropy: 0.0363318	valid_0's binary_logloss: 0.0363318	valid_0's auc: 0.997868
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [284]	valid_0's cross_entropy: 0.0363049	valid_0's binary_logloss: 0.0363049	valid_0's auc: 0.99787
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [285]	valid_0's cross_entropy: 0.0362969	valid_0's binary_logloss: 0.0362969	valid_0's auc: 0.997871
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [286]	valid_0's cross_entropy: 0.0362868	valid_0's binary_logloss: 0.0362868	valid_0's auc: 0.99787
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [287]	valid_0's cross_entropy: 0.0362789	valid_0's binary_logloss: 0.0362789	valid_0's auc: 0.997871
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [288]	valid_0's cross_entropy: 0.0362559	valid_0's binary_logloss: 0.0362559	valid_0's auc: 0.997872
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [289]	valid_0's cross_entropy: 0.0362304	valid_0's binary_logloss: 0.0362304	valid_0's auc: 0.997873
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [290]	valid_0's cross_entropy: 0.0362187	valid_0's binary_logloss: 0.0362187	valid_0's auc: 0.997872
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [291]	valid_0's cross_entropy: 0.0362122	valid_0's binary_logloss: 0.0362122	valid_0's auc: 0.997872
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [292]	valid_0's cross_entropy: 0.0361952	valid_0's binary_logloss: 0.0361952	valid_0's auc: 0.997872
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [293]	valid_0's cross_entropy: 0.036191	valid_0's binary_logloss: 0.036191	valid_0's auc: 0.997872
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [294]	valid_0's cross_entropy: 0.0361869	valid_0's binary_logloss: 0.0361869	valid_0's auc: 0.997872
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [295]	valid_0's cross_entropy: 0.0361756	valid_0's binary_logloss: 0.0361756	valid_0's auc: 0.997872
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [296]	valid_0's cross_entropy: 0.0361701	valid_0's binary_logloss: 0.0361701	valid_0's auc: 0.997871
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [297]	valid_0's cross_entropy: 0.036164	valid_0's binary_logloss: 0.036164	valid_0's auc: 0.997871
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [298]	valid_0's cross_entropy: 0.036158	valid_0's binary_logloss: 0.036158	valid_0's auc: 0.997871
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [299]	valid_0's cross_entropy: 0.0361242	valid_0's binary_logloss: 0.0361242	valid_0's auc: 0.997872
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [300]	valid_0's cross_entropy: 0.0361155	valid_0's binary_logloss: 0.0361155	valid_0's auc: 0.997872

# %%
from sklearn.metrics import precision_score, recall_score, roc_auc_score
y_pred = gbm.predict(X_test)
print('auc值：', roc_auc_score(y_test, y_pred))
# Out:
# auc值： 0.9978716600868143

# %%
fea_cols = [c for c in cols if c != 'label']

print(pd.DataFrame({
        'column': fea_cols,
        'importance': gbm.feature_importance(importance_type='gain'),
    }).sort_values(by='importance'))
# Out:
#    column    importance
# 3      C4  1.575813e+04
# 12    C13  1.763607e+04
# 13    C14  1.030285e+05
# 1      C2  1.157638e+05
# 15     I2  3.027119e+05
# 9     C10  3.054032e+05
# 14     I1  6.080994e+05
# 0      C1  6.874883e+05
# 4      C5  7.385032e+05
# 7      C8  9.332413e+05
# 5      C6  1.295243e+06
# 6      C7  1.839049e+06
# 2      C3  5.463211e+06
# 11    C12  8.249795e+06
# 8      C9  1.335486e+07
# 10    C11  2.042035e+07
